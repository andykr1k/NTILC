# %%
from pathlib import Path
import sys

cwd = Path.cwd()
project_root = cwd.parent if cwd.name == 'notebooks' else cwd
sys.path.insert(0, str(project_root))

# %%
from orchestrator import NTILCOrchestratorAgent

agent = NTILCOrchestratorAgent.from_pretrained( 
    intent_embedder_path="/scratch4/home/akrik/NTILC/checkpoints/best_model.pt",
    query_encoder_path="/scratch4/home/akrik/NTILC/checkpoints/cluster_retrieval/best_model.pt",
    qwen_model_name_or_path="Qwen/Qwen2.5-7B-Instruct",
    device="cuda:7",
)
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# `torch_dtype` is deprecated! Use `dtype` instead!
# ...
# Loading checkpoint shards: 100%|██████████| 4/4 [00:02<00:00,  1.66it/s]

# %%
result = agent.run("create a file at root")
# Out:
# 2026-02-23 21:29:21,362 | INFO | orchastrator.agent | run_started request=Get latest orders from CA and email a summary to ops@example.com
# 2026-02-23 21:29:25,131 | INFO | orchastrator.agent | plan_created actions=[{"id": 1, "instruction": "Fetch latest orders from CA API", "depends_on": []}, {"id": 2, "instruction": "Parse fetched orders data", "depends_on": [1]}, {"id": 3, "instruction": "Summarize parsed order data", "depends_on": [2]}, {"id": 4, "instruction": "Format summary as email body", "depends_on": [3]}, {"id": 5, "instruction": "Retrieve email credentials", "depends_on": []}, {"id": 6, "instruction": "Send email to ops@example.com", "depends_on": [4, 5]}, {"id": 7, "instruction": "Log email sending attempt", "depends_on": [6]}, {"id": 8, "instruction": "Handle any errors during process", "depends_on": [1, 2, 3, 4, 5, 6, 7]}]
# 2026-02-23 21:29:25,133 | INFO | orchastrator.agent | step_started id=1 instruction=Fetch latest orders from CA API depends_on=[]
# ...

# %%
print(result.to_dict())
# Out:
# {'request': 'Get latest orders from CA and email a summary to ops@example.com', 'atomic_actions': [{'id': 1, 'instruction': 'Fetch latest orders from CA API', 'depends_on': []}, {'id': 2, 'instruction': 'Parse fetched orders data', 'depends_on': [1]}, {'id': 3, 'instruction': 'Summarize parsed order data', 'depends_on': [2]}, {'id': 4, 'instruction': 'Format summary as email body', 'depends_on': [3]}, {'id': 5, 'instruction': 'Retrieve email credentials', 'depends_on': []}, {'id': 6, 'instruction': 'Send email to ops@example.com', 'depends_on': [4, 5]}, {'id': 7, 'instruction': 'Log email sending attempt', 'depends_on': [6]}, {'id': 8, 'instruction': 'Handle any errors during process', 'depends_on': [1, 2, 3, 4, 5, 6, 7]}], 'steps': [{'step_id': 1, 'action': 'Fetch latest orders from CA API', 'cluster_id': 4, 'confidence': 0.96484375, 'tool_name': 'web_fetch', 'arguments': {'url': 'https://api.ca.com/orders/latest', 'method': 'GET'}, 'tool_call': "web_fetch(url='https://api.ca.com/or
# ...
