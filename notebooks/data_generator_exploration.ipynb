# %% [markdown]
# # Data Generator Exploration
# Generate samples and inspect distributions and examples.

# %%
from pathlib import Path
import sys

cwd = Path.cwd()
project_root = cwd.parent if cwd.name == 'notebooks' else cwd
sys.path.insert(0, str(project_root))

# %%
import pandas as pd

from training.data_generator import NaturalLanguageToolCallGenerator, OutputFormat

# %%
generator = NaturalLanguageToolCallGenerator(output_format=OutputFormat.PYTHON)
num_samples = 300
data = [generator.generate_pair() for _ in range(num_samples)]

df = pd.DataFrame({
    'tool': [d['tool'] for d in data],
    'query': [d['query'] for d in data],
    'tool_call': [d['tool_call'] for d in data],
})

df.head(10)
# Out:
#         tool                                              query  \
# 0  file_read                                  Open the log file
# 1     search  Search the web for climate change best practic...
# 2  web_fetch                     Get posts from JSONPlaceholder
# 3  web_fetch                  Get comments from JSONPlaceholder
# 4     search  Please search machine learning tutorials and r...
# 5  web_fetch                  Get comments from JSONPlaceholder
# 6  calculate                 What is the absolute value of -42?
# 7     search  What can you find about AI papers? Show me 49 ...
# 8     search  Can you search for neural networks? I want 11 ...
# 9     search  Search for NLP overview and return up to 39 items
#
#                                            tool_call
# 0  file_read(path='/var/log/app.log', encoding='u...
# 1  search(query='climate change best practices', ...
# 2  web_fetch(url='https://jsonplaceholder.typicod...
# 3  web_fetch(url='https://jsonplaceholder.typicod...
# 4  search(query='machine learning tutorials', max...
# 5  web_fetch(url='https://jsonplaceholder.typicod...
# 6                   calculate(expression='abs(-42)')
# 7  search(query='AI papers', max_results=49, date...
# 8    search(query='neural networks', max_results=11)
# 9       search(query='NLP overview', max_results=39)

# %%
df['tool'].value_counts()
# Out:
# tool
# file_read         63
# search            53
# web_fetch         51
# calculate         46
# database_query    45
# send_email        42
# Name: count, dtype: int64

# %%
for tool in sorted(df['tool'].unique()):
    print(f'Tool: {tool}')
    display(df[df['tool'] == tool].head(5))
# Out:
# Tool: calculate
#          tool                               query  \
# 6   calculate  What is the absolute value of -42?
# 20  calculate  What is the absolute value of -42?
# 22  calculate        What's 88 to the power of 2?
# 25  calculate         What is the ceiling of 3.2?
# 27  calculate    Round 3.14159 to nearest integer
#
#                                  tool_call
# 6         calculate(expression='abs(-42)')
# 20        calculate(expression='abs(-42)')
# 22         calculate(expression='88 ** 2')
# 25       calculate(expression='ceil(3.2)')
# 27  calculate(expression='round(3.14159)')
# Tool: database_query
#               tool                                              query  \
# 11  database_query                List recent transactions over $1000
# 14  database_query             Count how many active products we have
# 38  database_query                        Top 10 customers by revenue
# 39  database_query                             Get all pending orders
# 49  database_query  Get total revenue from last quarter (timeout: ...
#
#                                             tool_call
# 11  database_query(sql='SELECT * FROM transactions...
# 14  database_query(sql='SELECT COUNT(*) FROM produ...
# 38  database_query(sql='SELECT customer_id, SUM(am...
# 39  database_query(sql='SELECT * FROM orders WHERE...
# 49  database_query(sql='SELECT SUM(amount) FROM tr...
# Tool: file_read
#          tool                    query  \
# 0   file_read        Open the log file
# 10  file_read    Open the training log
# 15  file_read   Read the settings file
# 16  file_read  Read the exports report
# 17  file_read        Open the log file
#
#                                             tool_call
# 0   file_read(path='/var/log/app.log', encoding='u...
# 10  file_read(path='logs/train_intent.log', encodi...
# 15  file_read(path='../config/settings.ini', encod...
# 16  file_read(path='./data/exports/report_2024.csv...
# 17  file_read(path='/var/log/app.log', encoding='u...
# Tool: search
#      tool                                              query  \
# 1  search  Search the web for climate change best practic...
# 4  search  Please search machine learning tutorials and r...
# 7  search  What can you find about AI papers? Show me 49 ...
# 8  search  Can you search for neural networks? I want 11 ...
# 9  search  Search for NLP overview and return up to 39 items
#
#                                            tool_call
# 1  search(query='climate change best practices', ...
# 4  search(query='machine learning tutorials', max...
# 7  search(query='AI papers', max_results=49, date...
# 8    search(query='neural networks', max_results=11)
# 9       search(query='NLP overview', max_results=39)
# Tool: send_email
#           tool                                              query  \
# 13  send_email  Send a thank you email to johnsonjoshua@exampl...
# 31  send_email  Email jillrhodes@example.net requesting feedba...
# 54  send_email  Email garzaanthony@example.org to follow up on...
# 57  send_email  Send jesseguzman@example.net a quick status up...
# 58  send_email  Email jennifermiles@example.com requesting fee...
#
#                                             tool_call
# 13  send_email(to='johnsonjoshua@example.org', sub...
# 31  send_email(to='jillrhodes@example.net', subjec...
# 54  send_email(to='garzaanthony@example.org', subj...
# 57  send_email(to='jesseguzman@example.net', subje...
# 58  send_email(to='jennifermiles@example.com', sub...
# Tool: web_fetch
#          tool                                   query  \
# 2   web_fetch          Get posts from JSONPlaceholder
# 3   web_fetch       Get comments from JSONPlaceholder
# 5   web_fetch       Get comments from JSONPlaceholder
# 18  web_fetch  Fetch weather data from OpenWeatherMap
# 19  web_fetch           Get data from the example API
#
#                                             tool_call
# 2   web_fetch(url='https://jsonplaceholder.typicod...
# 3   web_fetch(url='https://jsonplaceholder.typicod...
# 5   web_fetch(url='https://jsonplaceholder.typicod...
# 18  web_fetch(url='https://api.openweathermap.org/...
# 19  web_fetch(url='https://api.example.com/data', ...
